# %%
import os
import sqlite3
import pickle

import pandas as pd
from openai import OpenAI
from vanna.openai import OpenAI_Chat
from vanna.chromadb import ChromaDB_VectorStore

# %% [markdown]
# # Componentes

# %%
class MyVanna( ChromaDB_VectorStore, OpenAI_Chat):
    def __init__(self, config=None):
        ChromaDB_VectorStore.__init__(self, config=config)
        OpenAI_Chat.__init__(self, config=config)
        self.client = OpenAI(api_key=config['openai']['api_key'])

# %% [markdown]
# # Inicialização do Vanna

# %%
vn = MyVanna(
    config={
        'openai': {
            'api_key': os.getenv('OPENAI_API_KEY'),
            'model': 'gpt-3.5-turbo'
        },
        'chroma': {
            'persist_directory': 'chroma-db'
        }
    }
)

# %%
vn.connect_to_sqlite( url = 'db_olist.sqlite')

# %% [markdown]
# # Vanna Client

# %% [markdown]
# ## Treinamento Vanna com DLL

# %%
consulta_ddl = """
                SELECT
                    name, sql
                FROM
                    sqlite_master
                WHERE type = 'table'
                ORDER BY
                    name;
"""
#consulta_ddl = ""
#ddl_olist = vn.run_sql(consulta_ddl)

# %%
print(type(consulta_ddl))
print(consulta_ddl)
# Out:
# <class 'str'>
#
#                 SELECT
#                     name, sql
#                 FROM
#                     sqlite_master
#                 WHERE type = 'table'
#                 ORDER BY
#                     name;

# %%
pickle.dump(consulta_ddl, open("../src/arquivos_treinamento/consulta_ddl.pkl", "wb"))

# %%
treinamento = 0
for _, row in ddl_olist.iterrows():
    tbl, ddl = row['name'], row['sql']
    if isinstance (ddl, str) and ddl.strip():
        vn.train(ddl = ddl)
        treinamento += 1
        print(f'DDL registrado: {ddl}')
print(f'[ok] Tabelas treinadas: {treinamento}')
# Out:
# Adding ddl: CREATE TABLE customer(
#     customer_id                 TEXT,
#     customer_unique_id          TEXT,
#     customer_zip_code_prefix    INTEGER,
#     customer_city               TEXT,
#     customer_state              TEXT
# )
# DDL registrado: CREATE TABLE customer(
#     customer_id                 TEXT,
#     customer_unique_id          TEXT,
#     customer_zip_code_prefix    INTEGER,
#     customer_city               TEXT,
#     customer_state              TEXT
# )
# Adding ddl: CREATE TABLE geolocation(
#     geolocation_zip_code_prefix    INTEGER,
#     geolocation_lat                REAL,
#     geolocation_lng                REAL,
#     geolocation_city               TEXT,
#     geolocation_state              TEXT
# )
# DDL registrado: CREATE TABLE geolocation(
#     geolocation_zip_code_prefix    INTEGER,
#     geolocation_lat                REAL,
#     geolocation_lng                REAL,
#     geolocation_city               TEXT,
#     geolocation_state              TEXT
# )
# Adding ddl: CREATE TABLE order_items(
#     order_id               TEXT,
#     order_item_id          INTEGER,
#     product_id             TEXT,
#     seller_id              TEXT,
#     shipping_limit_date    TEXT,
#     price                  REAL,
#     freight_value          REAL
# )
# DDL registrado: CREATE TABLE order_items(
#     order_id               TEXT,
#     order_item_id          INTEGER,
#     product_id             TEXT,
#     seller_id              TEXT,
#     shipping_limit_date    TEXT,
#     price                  REAL,
#     freight_value          REAL
# )
# Adding ddl: CREATE TABLE order_payments(
#     order_id                 TEXT,
#     payment_sequential       INTEGER,
#     payment_type             TEXT,
#     payment_installments     INTEGER,
#     payment_value            REAL
# )
# DDL registrado: CREATE TABLE order_payments(
#     order_id                 TEXT,
#     payment_sequential       INTEGER,
#     payment_type             TEXT,
#     payment_installments     INTEGER,
#     payment_value            REAL
# )
# Adding ddl: CREATE TABLE order_review_backup (
# 	review_id               TEXT NOT NULL,
# 	order_id                TEXT,
# 	review_score            INTEGER,
# 	review_comment_title    TEXT,
# 	review_comment_message  TEXT,
# 	review_creation_date    TIMESTAMP,
# 	review_answer_timestamp TIMESTAMP
# )
# DDL registrado: CREATE TABLE order_review_backup (
# 	review_id               TEXT NOT NULL,
# 	order_id                TEXT,
# 	review_score            INTEGER,
# 	review_comment_title    TEXT,
# 	review_comment_message  TEXT,
# 	review_creation_date    TIMESTAMP,
# 	review_answer_timestamp TIMESTAMP
# )
# Adding ddl: CREATE TABLE order_review_shorts (
# 	review_id               TEXT NOT NULL,
# 	order_id                TEXT,
# 	review_score            INTEGER,
# 	review_comment_title    TEXT,
# 	review_comment_message  TEXT,
# 	review_creation_date    TIMESTAMP,
# 	review_answer_timestamp TIMESTAMP
# )
# DDL registrado: CREATE TABLE order_review_shorts (
# 	review_id               TEXT NOT NULL,
# 	order_id                TEXT,
# 	review_score            INTEGER,
# 	review_comment_title    TEXT,
# 	review_comment_message  TEXT,
# 	review_creation_date    TIMESTAMP,
# 	review_answer_timestamp TIMESTAMP
# )
# Adding ddl: CREATE TABLE order_reviews(
#     review_id                  TEXT,
#     order_id                   TEXT,
#     review_score               INTEGER,
#     review_comment_title       TEXT,
#     review_comment_message     TEXT,
#     review_creation_date       TEXT,
#     review_answer_timestamp    TEXT
# )
# DDL registrado: CREATE TABLE order_reviews(
#     review_id                  TEXT,
#     order_id                   TEXT,
#     review_score               INTEGER,
#     review_comment_title       TEXT,
#     review_comment_message     TEXT,
#     review_creation_date       TEXT,
#     review_answer_timestamp    TEXT
# )
# Adding ddl: CREATE TABLE orders(
#     order_id                         TEXT,
#     customer_id                      TEXT,
#     order_status                     TEXT,
#     order_purchase_timestamp         TEXT,
#     order_approved_at                TEXT,
#     order_delivered_carrier_date     TEXT,
#     order_delivered_customer_date    TEXT,
#     order_estimated_delivery_date    TEXT
# )
# DDL registrado: CREATE TABLE orders(
#     order_id                         TEXT,
#     customer_id                      TEXT,
#     order_status                     TEXT,
#     order_purchase_timestamp         TEXT,
#     order_approved_at                TEXT,
#     order_delivered_carrier_date     TEXT,
#     order_delivered_customer_date    TEXT,
#     order_estimated_delivery_date    TEXT
# )
# Adding ddl: CREATE TABLE product_category_name(
#     product_category_name            TEXT,
#     product_category_name_english    TEXT
# )
# DDL registrado: CREATE TABLE product_category_name(
#     product_category_name            TEXT,
#     product_category_name_english    TEXT
# )
# Adding ddl: CREATE TABLE products(
#     product_id                    TEXT,
#     product_category_name         TEXT,
#     product_name_lenght           REAL,
#     product_description_lenght    REAL,
#     product_photos_qty            REAL,
#     product_weight_g              REAL,
#     product_length_cm             REAL,
#     product_height_cm             REAL,
#     product_width_cm              REAL
# )
# DDL registrado: CREATE TABLE products(
#     product_id                    TEXT,
#     product_category_name         TEXT,
#     product_name_lenght           REAL,
#     product_description_lenght    REAL,
#     product_photos_qty            REAL,
#     product_weight_g              REAL,
#     product_length_cm             REAL,
#     product_height_cm             REAL,
#     product_width_cm              REAL
# )
# Adding ddl: CREATE TABLE sellers(
#     seller_id                 TEXT,
#     seller_zip_code_prefix    INTEGER,
#     seller_city               TEXT,
#     seller_state              TEXT
# )
# DDL registrado: CREATE TABLE sellers(
#     seller_id                 TEXT,
#     seller_zip_code_prefix    INTEGER,
#     seller_city               TEXT,
#     seller_state              TEXT
# )
# [ok] Tabelas treinadas: 11

# %%
vn.get_training_data()
# Out:
#                                           id  \
# 0   60a4b723-6559-537a-bb2e-00de362af570-sql
# 1   ca3cedc5-8c43-522f-9376-5adf9e0dcf9d-sql
# 2   fa151c51-8af2-5f47-8a63-9f3aa08e9d1b-sql
# 3   3e8e4ed6-4544-5df0-895d-fb76fb4f6ac7-sql
# 4   92526b98-007c-519c-9b0e-2b9de94e0cc5-sql
# 5   9836d950-8995-517b-8ec1-860e14d8e1da-sql
# 6   873c4917-95dc-5804-8505-4101d51ea68b-sql
# 7   1a0ef8ea-9dc0-50bd-a417-bb738b8b6508-sql
# 8   d9fcda27-c25a-5a92-a8c7-1463d0d00a36-sql
# 9   af6a6b71-9238-5cc4-9903-c97ca99a4be5-sql
# 0   cbfd11d3-9114-58e7-b3a6-111d46188360-ddl
# 1   ed7d3c96-8bfb-55da-b6af-d55b6bce6418-ddl
# 2   8c734f07-49b1-5e1a-984b-b1ef3e10fac8-ddl
# 3   f01472c1-90e1-5877-95a4-9a2c6b701173-ddl
# 4   9bab394c-c8ed-5e42-97a8-f741e5e21c85-ddl
# 5   5ebeea56-9273-5381-9222-852f2ba4a4c3-ddl
# 6   75b917f3-829f-5022-bccf-211fc9e14e12-ddl
# 7   c5903464-875c-5b19-bd93-000e79217a4d-ddl
# 8   d56e42a5-118f-5846-93a7-f5b8521ec7a7-ddl
# 9   691e6822-1c45-5a1e-b146-1395ca68d408-ddl
# 10  e4a04401-ec06-5f55-a4d2-2cace7820bb1-ddl
# 0   47d073c2-88ee-5408-acbf-918563368ac7-doc
# 1   40640826-e48e-5ce2-be20-51b64ecb3435-doc
# 2   c31e12aa-ab24-58a3-819e-fbd4f138af35-doc
# 3   101df5d1-1ee5-59d4-abc6-f226c22e78eb-doc
# 4   7c3e4c88-9323-5aaa-af7f-ba566548e4c7-doc
# 5   fc8401f7-19ef-5157-8d2f-effff18351b4-doc
# 6   97ff94d8-cbda-557a-af9d-1157ea4f0b6b-doc
# 7   8027fffa-61f3-5c32-8f6a-bf91b2e99443-doc
# 8   5a452a2d-5ab1-5924-a5fe-ef3cd6845e34-doc
# 9   21932e31-7bb5-5f2a-a761-398f949920a8-doc
# 10  0a608eda-5aed-54b7-8211-d986c9140804-doc
# 11  793575c5-f9f8-5d22-9754-b9fef8d526b0-doc
# 12  d694f21e-259d-5dd6-a44b-49708e9f5eae-doc
# 13  ef4d7275-aa94-5358-bff6-87fbfd2049dc-doc
# 14  a5668e5a-e15b-5631-bb8a-0699a996ec7d-doc
# 15  c175c9c4-08d2-5ccc-bc5e-9a0cdde49821-doc
# 16  4309243c-0e57-50e8-8fcb-971120afd397-doc
#
#                                              question  \
# 0   Calcule o GMV (soma do price) e o nº de pedido...
# 1   Liste as 5 categorias com mais itens vendidos ...
# 2   Calcule o valor médio de pagamento por tipo de...
# 3   Tempo médio de entrega (em dias) por estado do...
# 4   Taxa de cancelamento por mês (considerando ord...
# 5   Para cada seller, calcule o GMV total (soma do...
# 6   Top 3 sellers por GMV em cada mês (ranking men...
# 7   GMV mensal e GMV acumulado móvel de 3 meses (j...
# 8   Atraso vs estimativa: % de pedidos entregues a...
# 9   Atraso vs estimativa: '%' de pedidos entregues...
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
#
#                                               content training_data_type
# 0   \n            SELECT\n                STRFTIME...                sql
# 1   \n            SELECT\n                p.produc...                sql
# 2   \n            SELECT\n                op.payme...                sql
# 3   \n            SELECT\n                c.custom...                sql
# 4   \n            SELECT\n                STRFTIME...                sql
# 5   \n            SELECT\n                oi.selle...                sql
# 6   \n            WITH seller_month AS (\n        ...                sql
# 7   \n            WITH monthly AS (\n             ...                sql
# 8   \n            WITH late_table AS (\n          ...                sql
# 9   \n            WITH late_table AS (\n          ...                sql
# 0   CREATE TABLE customer( \n    customer_id      ...                ddl
# 1   CREATE TABLE geolocation( \n    geolocation_zi...                ddl
# 2   CREATE TABLE order_items( \n    order_id      ...                ddl
# 3   CREATE TABLE order_payments( \n    order_id   ...                ddl
# 4   CREATE TABLE order_review_backup (\n\treview_i...                ddl
# 5   CREATE TABLE order_review_shorts (\n\treview_i...                ddl
# 6   CREATE TABLE order_reviews( \n    review_id   ...                ddl
# 7   CREATE TABLE orders( \n    order_id           ...                ddl
# 8   CREATE TABLE product_category_name( \n    prod...                ddl
# 9   CREATE TABLE products( \n    product_id       ...                ddl
# 10  CREATE TABLE sellers( \n    seller_id         ...                ddl
# 0   Tabela `orders` contém pedidos, status, timest...      documentation
# 1   Tabela `customers` contém informações dos clie...      documentation
# 2   Tabela `order_items` contém os itens de cada p...      documentation
# 3   Tabela `products` contém categorias e informaç...      documentation
# 4   Tabela `sellers` contém vendedores, localizaçã...      documentation
# 5   Tabela `payments` contém pagamentos de cada pe...      documentation
# 6   Tabela `reviews` contém avaliações de clientes...      documentation
# 7   A tabela `orders` se conecta à tabela `custome...      documentation
# 8   A tabela `orders` se conecta à tabela `order_i...      documentation
# 9   A tabela `orders` se conecta à tabela `order_p...      documentation
# 10  A tabela `orders` se conecta à tabela `order_r...      documentation
# 11  A tabela `order_items` se conecta à tabela `pr...      documentation
# 12  A tabela `order_items` se conecta à tabela `se...      documentation
# 13  A tabela `sellers` se conecta à tabela `geoloc...      documentation
# 14  A tabela `customers` se conecta à tabela `geol...      documentation
# 15  Sempre utilize a função strftime no formato '%...      documentation
# 16  Nunca utilize '%y-%m' ou outros formatos de st...      documentation

# %% [markdown]
# ## Treinamento Vanna via Perguntas e SQL

# %%
queries = [
    {
        "question": (
            "Calcule o GMV (soma do price) e o nº de pedidos por mês de compra. "
            "Saídas: year_month, orders_cnt, gmv"
        ),
        "sql": """
            SELECT
                STRFTIME('%Y-%m', o.order_purchase_timestamp) AS year_month,
                COUNT(DISTINCT o.order_id) AS orders_cnt,
                SUM(price) AS gmv
            FROM orders o
            LEFT JOIN order_items i
                ON i.order_id = o.order_id
            GROUP BY year_month
            ORDER BY year_month;
        """,
    },
    {
        "question": (
            "Liste as 5 categorias com mais itens vendidos (quantidade de linhas em order_items). "
            "Saídas: product_category_name, itens_vendidos"
        ),
        "sql": """
            SELECT
                p.product_category_name,
                COUNT(*) AS itens_vendidos
            FROM order_items i
            LEFT JOIN products p
                ON p.product_id = i.product_id
            GROUP BY p.product_category_name
            ORDER BY itens_vendidos DESC
            LIMIT 5;
        """,
    },
    {
        "question": (
            "Calcule o valor médio de pagamento por tipo de pagamento. "
            "Saídas: payment_type, avg_payment_value"
        ),
        "sql": """
            SELECT
                op.payment_type,
                AVG(op.payment_value) AS avg_payment_value
            FROM order_payments op
            GROUP BY payment_type
            ORDER BY avg_payment_value DESC;
        """,
    },
    {
        "question": (
            "Tempo médio de entrega (em dias) por estado do cliente. "
            "Saídas: customer_state, avg_delivery_days"
        ),
        "sql": """
            SELECT
                c.customer_state,
                AVG(
                    julianday(o.order_delivered_customer_date)
                    - julianday(o.order_purchase_timestamp)
                ) AS avg_delivery_days
            FROM orders o
            INNER JOIN customer c
                ON c.customer_id = o.customer_id
            WHERE o.order_delivered_customer_date IS NOT NULL
            GROUP BY c.customer_state
            ORDER BY avg_delivery_days;
        """,
    },
    {
        "question": (
            "Taxa de cancelamento por mês (considerando order_status = 'canceled'). "
            "Saídas: year_month, orders_cnt, canceled_cnt, cancel_rate"
        ),
        "sql": """
            SELECT
                STRFTIME('%Y-%m', o.order_purchase_timestamp) AS year_month,
                COUNT(*) AS orders_cnt,
                SUM(CASE WHEN o.order_status = 'canceled' THEN 1 ELSE 0 END) AS canceled_cnt,
                CAST(
                    SUM(CASE WHEN o.order_status = 'canceled' THEN 1 ELSE 0 END) AS REAL
                ) / COUNT(*) AS cancel_rate
            FROM orders o
            GROUP BY year_month
            ORDER BY year_month;
        """,
    },
    {
        "question": (
            "Para cada seller, calcule o GMV total (soma do price) e o nº de pedidos únicos. "
            "Saídas: seller_id, orders_cnt, gmv"
        ),
        "sql": """
            SELECT
                oi.seller_id,
                COUNT(DISTINCT o.order_id) AS orders_cnt,
                ROUND(SUM(oi.price), 2) AS gmv
            FROM orders o
            LEFT JOIN order_items oi
                ON oi.order_id = o.order_id
            GROUP BY oi.seller_id
            ORDER BY gmv DESC, orders_cnt DESC;
        """,
    },
    {
        "question": (
            "Top 3 sellers por GMV em cada mês (ranking mensal usando janela). "
            "Saídas: year_month, seller_id, gmv, rn"
        ),
        "sql": """
            WITH seller_month AS (
                SELECT
                    STRFTIME('%Y-%m', o.order_purchase_timestamp) AS year_month,
                    oi.seller_id,
                    SUM(oi.price) AS gmv
                FROM orders o
                LEFT JOIN order_items oi
                    ON oi.order_id = o.order_id
                GROUP BY year_month, oi.seller_id
            ),
            ranked AS (
                SELECT
                    year_month,
                    seller_id,
                    gmv,
                    ROW_NUMBER() OVER (
                        PARTITION BY year_month
                        ORDER BY gmv DESC
                    ) AS rn
                FROM seller_month
            )
            SELECT
                year_month, seller_id, gmv, rn
            FROM ranked
            WHERE rn <= 3
            ORDER BY year_month, rn, gmv DESC;
        """,
    },
    {
        "question": (
            "GMV mensal e GMV acumulado móvel de 3 meses (janela). "
            "Saídas: year_month, gmv_mth, gmv_3m_rolling"
        ),
        "sql": """
            WITH monthly AS (
                SELECT
                    STRFTIME('%Y-%m', o.order_purchase_timestamp) AS year_month,
                    SUM(i.price) AS gmv_mth
                FROM orders o
                JOIN order_items i
                    ON i.order_id = o.order_id
                GROUP BY year_month
            )
            SELECT
                year_month,
                gmv_mth,
                SUM(gmv_mth) OVER (
                    ORDER BY year_month
                    ROWS BETWEEN 2 PRECEDING AND CURRENT ROW
                ) AS gmv_3m_rolling
            FROM monthly
            ORDER BY year_month;
        """,
    },
    {
        "question": (
            "Atraso vs estimativa: '%' de pedidos entregues após order_estimated_delivery_date, por UF do cliente (top 10 por volume). "
            "Saídas: customer_state, late_delivery_rate, orders_cnt"
        ),
        "sql": """
            WITH late_table AS (
                SELECT
                    g.geolocation_state AS customer_state,
                    COUNT(o.order_id) AS orders_cnt,
                    SUM(
                        CASE
                            WHEN o.order_delivered_customer_date > o.order_estimated_delivery_date
                            THEN 1 ELSE 0
                        END
                    ) AS late_delivery
                FROM orders o
                INNER JOIN customer c
                    ON c.customer_id = o.customer_id
                INNER JOIN geolocation g
                    ON g.geolocation_zip_code_prefix = c.customer_zip_code_prefix
                GROUP BY g.geolocation_state
            )
            SELECT
                customer_state,
                orders_cnt,
                CAST(late_delivery AS REAL) / orders_cnt AS late_delivery_rate
            FROM late_table
            ORDER BY orders_cnt DESC
            -- LIMIT 10  -- descomente para manter apenas o top 10 por volume
            ;
        """,
    },
]

# %%
with open("../src/arquivos_treinamento/qa.pkl","wb") as f:
    pickle.dump(queries,f)

# %%
for q in queries:
    vn.train(question=q["question"], sql=q["sql"])

# %%
df_teste = pd.DataFrame(queries)

# %%
for i in range(len(df_teste)):
    question = df_teste['question'][i]
    sql = df_teste['sql'][i]
    print(f"Iteração: {i} \n Question : {question} \n SQL: {sql} \n")

#for q in range(len(df_teste)):
#    print(df_teste.)
# Out:
# Iteração: 0
#  Question : Calcule o GMV (soma do price) e o nº de pedidos por mês de compra. Saídas: year_month, orders_cnt, gmv
#  SQL:
#             SELECT
#                 STRFTIME('%Y-%m', o.order_purchase_timestamp) AS year_month,
#                 COUNT(DISTINCT o.order_id) AS orders_cnt,
#                 SUM(price) AS gmv
#             FROM orders o
#             LEFT JOIN order_items i
#                 ON i.order_id = o.order_id
#             GROUP BY year_month
#             ORDER BY year_month;
#
#
# Iteração: 1
#  Question : Liste as 5 categorias com mais itens vendidos (quantidade de linhas em order_items). Saídas: product_category_name, itens_vendidos
#  SQL:
#             SELECT
#                 p.product_category_name,
#                 COUNT(*) AS itens_vendidos
#             FROM order_items i
#             LEFT JOIN products p
#                 ON p.product_id = i.product_id
#             GROUP BY p.product_category_name
#             ORDER BY itens_vendidos DESC
#             LIMIT 5;
#
#
# Iteração: 2
#  Question : Calcule o valor médio de pagamento por tipo de pagamento. Saídas: payment_type, avg_payment_value
#  SQL:
#             SELECT
#                 op.payment_type,
#                 AVG(op.payment_value) AS avg_payment_value
#             FROM order_payments op
#             GROUP BY payment_type
#             ORDER BY avg_payment_value DESC;
#
#
# Iteração: 3
#  Question : Tempo médio de entrega (em dias) por estado do cliente. Saídas: customer_state, avg_delivery_days
#  SQL:
#             SELECT
#                 c.customer_state,
#                 AVG(
#                     julianday(o.order_delivered_customer_date)
#                     - julianday(o.order_purchase_timestamp)
#                 ) AS avg_delivery_days
#             FROM orders o
#             INNER JOIN customer c
#                 ON c.customer_id = o.customer_id
#             WHERE o.order_delivered_customer_date IS NOT NULL
#             GROUP BY c.customer_state
#             ORDER BY avg_delivery_days;
#
#
# Iteração: 4
#  Question : Taxa de cancelamento por mês (considerando order_status = 'canceled'). Saídas: year_month, orders_cnt, canceled_cnt, cancel_rate
#  SQL:
#             SELECT
#                 STRFTIME('%Y-%m', o.order_purchase_timestamp) AS year_month,
#                 COUNT(*) AS orders_cnt,
#                 SUM(CASE WHEN o.order_status = 'canceled' THEN 1 ELSE 0 END) AS canceled_cnt,
#                 CAST(
#                     SUM(CASE WHEN o.order_status = 'canceled' THEN 1 ELSE 0 END) AS REAL
#                 ) / COUNT(*) AS cancel_rate
#             FROM orders o
#             GROUP BY year_month
#             ORDER BY year_month;
#
#
# Iteração: 5
#  Question : Para cada seller, calcule o GMV total (soma do price) e o nº de pedidos únicos. Saídas: seller_id, orders_cnt, gmv
#  SQL:
#             SELECT
#                 oi.seller_id,
#                 COUNT(DISTINCT o.order_id) AS orders_cnt,
#                 ROUND(SUM(oi.price), 2) AS gmv
#             FROM orders o
#             LEFT JOIN order_items oi
#                 ON oi.order_id = o.order_id
#             GROUP BY oi.seller_id
#             ORDER BY gmv DESC, orders_cnt DESC;
#
#
# Iteração: 6
#  Question : Top 3 sellers por GMV em cada mês (ranking mensal usando janela). Saídas: year_month, seller_id, gmv, rn
#  SQL:
#             WITH seller_month AS (
#                 SELECT
#                     STRFTIME('%Y-%m', o.order_purchase_timestamp) AS year_month,
#                     oi.seller_id,
#                     SUM(oi.price) AS gmv
#                 FROM orders o
#                 LEFT JOIN order_items oi
#                     ON oi.order_id = o.order_id
#                 GROUP BY year_month, oi.seller_id
#             ),
#             ranked AS (
#                 SELECT
#                     year_month,
#                     seller_id,
#                     gmv,
#                     ROW_NUMBER() OVER (
#                         PARTITION BY year_month
#                         ORDER BY gmv DESC
#                     ) AS rn
#                 FROM seller_month
#             )
#             SELECT
#                 year_month, seller_id, gmv, rn
#             FROM ranked
#             WHERE rn <= 3
#             ORDER BY year_month, rn, gmv DESC;
#
#
# Iteração: 7
#  Question : GMV mensal e GMV acumulado móvel de 3 meses (janela). Saídas: year_month, gmv_mth, gmv_3m_rolling
#  SQL:
#             WITH monthly AS (
#                 SELECT
#                     STRFTIME('%Y-%m', o.order_purchase_timestamp) AS year_month,
#                     SUM(i.price) AS gmv_mth
#                 FROM orders o
#                 JOIN order_items i
#                     ON i.order_id = o.order_id
#                 GROUP BY year_month
#             )
#             SELECT
#                 year_month,
#                 gmv_mth,
#                 SUM(gmv_mth) OVER (
#                     ORDER BY year_month
#                     ROWS BETWEEN 2 PRECEDING AND CURRENT ROW
#                 ) AS gmv_3m_rolling
#             FROM monthly
#             ORDER BY year_month;
#
#
# Iteração: 8
#  Question : Atraso vs estimativa: '%' de pedidos entregues após order_estimated_delivery_date, por UF do cliente (top 10 por volume). Saídas: customer_state, late_delivery_rate, orders_cnt
#  SQL:
#             WITH late_table AS (
#                 SELECT
#                     g.geolocation_state AS customer_state,
#                     COUNT(o.order_id) AS orders_cnt,
#                     SUM(
#                         CASE
#                             WHEN o.order_delivered_customer_date > o.order_estimated_delivery_date
#                             THEN 1 ELSE 0
#                         END
#                     ) AS late_delivery
#                 FROM orders o
#                 INNER JOIN customer c
#                     ON c.customer_id = o.customer_id
#                 INNER JOIN geolocation g
#                     ON g.geolocation_zip_code_prefix = c.customer_zip_code_prefix
#                 GROUP BY g.geolocation_state
#             )
#             SELECT
#                 customer_state,
#                 orders_cnt,
#                 CAST(late_delivery AS REAL) / orders_cnt AS late_delivery_rate
#             FROM late_table
#             ORDER BY orders_cnt DESC
#             -- LIMIT 10  -- descomente para manter apenas o top 10 por volume
#             ;

# %% [markdown]
# ## Treinamento Vanna via Documentação

# %%
documentations = [
    # --- Descrições simples ---
    "Tabela `orders` contém pedidos, status, timestamps de compra e entrega.",
    "Tabela `customers` contém informações dos clientes e CEP.",
    "Tabela `order_items` contém os itens de cada pedido, com preço e frete.",
    "Tabela `products` contém categorias e informações de produtos.",
    "Tabela `sellers` contém vendedores, localização e identificação.",
    "Tabela `payments` contém pagamentos de cada pedido.",
    "Tabela `reviews` contém avaliações de clientes sobre pedidos.",

    # --- Relações entre tabelas da Olist ---
    "A tabela `orders` se conecta à tabela `customers` pela coluna `customer_id` usando INNER JOIN.",
    "A tabela `orders` se conecta à tabela `order_items` pela coluna `order_id` usando LEFT JOIN (um pedido pode ter mais de um item).",
    "A tabela `orders` se conecta à tabela `order_payments` pela coluna `order_id` usando LEFT JOIN (nem todo pedido tem pagamento completo registrado).",
    "A tabela `orders` se conecta à tabela `order_reviews` pela coluna `order_id` usando LEFT JOIN (nem todo pedido possui review).",
    "A tabela `order_items` se conecta à tabela `products` pela coluna `product_id` usando LEFT JOIN (pois alguns produtos podem não estar catalogados).",
    "A tabela `order_items` se conecta à tabela `sellers` pela coluna `seller_id` usando INNER JOIN.",
    "A tabela `sellers` se conecta à tabela `geolocation` pela coluna `zip_code_prefix` usando INNER JOIN.",
    "A tabela `customers` se conecta à tabela `geolocation` pela coluna `zip_code_prefix` usando INNER JOIN.",

    # --- Boas práticas de data ---
    "Sempre utilize a função strftime no formato '%Y-%m' para gerar ano e mês no SQLite.",
    "Nunca utilize '%y-%m' ou outros formatos de strftime, apenas '%Y-%m'."
]

# %%
with open("../src/arquivos_treinamento/documentations.pkl", "wb") as f:
    pickle.dump(documentations,f)

# %%
# Exemplo de uso:
for doc in documentations:
    vn.train(documentation=doc)
# Out:
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....
# Adding documentation....

# %% [markdown]
# ## Treinamento Vanna Prompt

# %%
config_prompt = """Você é um especialista em SQL para SQLite.Sempre que precisar agrupar ou formatar datas por ano e mês, 
                    use: strftime('%Y-%m', coluna_data)Nunca use '%y-%m' ou outros formatos.Sua resposta deve ser
                    **somente a query SQL válida**
                    sem comentários nem explicações.Nunca responda com texto, apenas SQL executável.
                    Não invente colunas. Não use outras formas
                    de join.Sempre coloque na esquerda a tabela de referência para fazer os joins."""

vn.config["sql_prompt_preamble"] = config_prompt

# %%
with open("../src/arquivos_treinamento/prompt.pkl", "wb") as f:
    pickle.dump(config_prompt, f)

# %% [markdown]
# # Geração da consulta SQL

# %%
pergunta = "Liste os 10 maiores consumidores e o total em valor e a quantidade de produtos que ele comprou"

sql = vn.generate_sql(question = pergunta)
# Out:
# SQL Prompt: [{'role': 'system', 'content': "You are a SQLite expert. Please help to generate a SQL query to answer the question. Your response should ONLY be based on the given context and follow the response guidelines and format instructions. \n===Tables \nCREATE TABLE order_items( \n    order_id               TEXT,\n    order_item_id          INTEGER,\n    product_id             TEXT,\n    seller_id              TEXT,\n    shipping_limit_date    TEXT,\n    price                  REAL,\n    freight_value          REAL\n)\n\nCREATE TABLE products( \n    product_id                    TEXT,\n    product_category_name         TEXT,\n    product_name_lenght           REAL,\n    product_description_lenght    REAL,\n    product_photos_qty            REAL,\n    product_weight_g              REAL,\n    product_length_cm             REAL,\n    product_height_cm             REAL,\n    product_width_cm              REAL\n)\n\nCREATE TABLE product_category_name( \n    product_category_name            TEXT,\n    product_category_name_english    TEXT\n)\n\nCREATE TABLE orders( \n    order_id                         TEXT,\n    customer_id                      TEXT,\n    order_status                     TEXT,\n    order_purchase_timestamp         TEXT,\n    order_approved_at                TEXT,\n    order_delivered_carrier_date     TEXT,\n    order_delivered_customer_date    TEXT,\n    order_estimated_delivery_date    TEXT\n)\n\nCREATE TABLE sellers( \n    seller_id                 TEXT,\n    seller_zip_code_prefix    INTEGER,\n    seller_city               TEXT,\n    seller_state              TEXT\n)\n\nCREATE TABLE order_reviews( \n    review_id                  TEXT,\n    order_id                   TEXT,\n    review_score               INTEGER,\n    review_comment_title       TEXT,\n    review_comment_message     TEXT,\n    review_creation_date       TEXT,\n    review_answer_timestamp    TEXT\n)\n\nCREATE TABLE order_payments( \n    order_id                 TEXT,\n    payment_sequential       INTEGER,\n    payment_type             TEXT,\n    payment_installments     INTEGER,\n    payment_value            REAL\n)\n\nCREATE TABLE customer( \n    customer_id                 TEXT,\n    customer_unique_id          TEXT,\n    customer_zip_code_prefix    INTEGER,  \n    customer_city               TEXT,\n    customer_state              TEXT\n)\n\nCREATE TABLE order_review_backup (\n\treview_id               TEXT NOT NULL, \n\torder_id                TEXT,\n\treview_score            INTEGER,\n\treview_comment_title    TEXT,\n\treview_comment_message  TEXT,\n\treview_creation_date    TIMESTAMP,\n\treview_answer_timestamp TIMESTAMP\n)\n\nCREATE TABLE order_review_shorts (\n\treview_id               TEXT NOT NULL, \n\torder_id                TEXT,\n\treview_score            INTEGER,\n\treview_comment_title    TEXT,\n\treview_comment_message  TEXT,\n\treview_creation_date    TIMESTAMP,\n\treview_answer_timestamp TIMESTAMP\n)\n\n\n===Additional Context \n\nTabela `products` contém categorias e informações de produtos.\n\nTabela `reviews` contém avaliações de clientes sobre pedidos.\n\nTabela `sellers` contém vendedores, localização e identificação.\n\nA tabela `order_items` se conecta à tabela `products` pela coluna `product_id` usando LEFT JOIN (pois alguns produtos podem não estar catalogados).\n\nTabela `order_items` contém os itens de cada pedido, com preço e frete.\n\nTabela `customers` contém informações dos clientes e CEP.\n\nTabela `orders` contém pedidos, status, timestamps de compra e entrega.\n\nSempre utilize a função strftime no formato '%Y-%m' para gerar ano e mês no SQLite.\n\nTabela `payments` contém pagamentos de cada pedido.\n\nA tabela `orders` se conecta à tabela `order_items` pela coluna `order_id` usando LEFT JOIN (um pedido pode ter mais de um item).\n\n===Response Guidelines \n1. If the provided context is sufficient, please generate a valid SQL query without any explanations for the question. \n2. If the provided context is a ...
# Using model gpt-3.5-turbo for 2910.75 tokens (approx)
# LLM Response:             SELECT
#                 c.customer_id,
#                 SUM(op.payment_value) AS total_value,
#                 COUNT(DISTINCT oi.product_id) AS products_bought
#             FROM customer c
#             LEFT JOIN orders o ON c.customer_id = o.customer_id
#             LEFT JOIN order_payments op ON o.order_id = op.order_id
#             LEFT JOIN order_items oi ON o.order_id = oi.order_id
#             GROUP BY c.customer_id
#             ORDER BY total_value DESC
#             LIMIT 10;

# %%
pergunta = "Faça um rank dos melhores vendedores do mês 08/2018, por valor de venda naquele mês. Acrescente o total de itens vendidos para cada vendedor."

sql = vn.generate_sql(question = pergunta)
# Out:
# SQL Prompt: [{'role': 'system', 'content': "You are a SQLite expert. Please help to generate a SQL query to answer the question. Your response should ONLY be based on the given context and follow the response guidelines and format instructions. \n===Tables \nCREATE TABLE order_reviews( \n    review_id                  TEXT,\n    order_id                   TEXT,\n    review_score               INTEGER,\n    review_comment_title       TEXT,\n    review_comment_message     TEXT,\n    review_creation_date       TEXT,\n    review_answer_timestamp    TEXT\n)\n\nCREATE TABLE order_items( \n    order_id               TEXT,\n    order_item_id          INTEGER,\n    product_id             TEXT,\n    seller_id              TEXT,\n    shipping_limit_date    TEXT,\n    price                  REAL,\n    freight_value          REAL\n)\n\nCREATE TABLE orders( \n    order_id                         TEXT,\n    customer_id                      TEXT,\n    order_status                     TEXT,\n    order_purchase_timestamp         TEXT,\n    order_approved_at                TEXT,\n    order_delivered_carrier_date     TEXT,\n    order_delivered_customer_date    TEXT,\n    order_estimated_delivery_date    TEXT\n)\n\nCREATE TABLE order_review_shorts (\n\treview_id               TEXT NOT NULL, \n\torder_id                TEXT,\n\treview_score            INTEGER,\n\treview_comment_title    TEXT,\n\treview_comment_message  TEXT,\n\treview_creation_date    TIMESTAMP,\n\treview_answer_timestamp TIMESTAMP\n)\n\nCREATE TABLE order_review_backup (\n\treview_id               TEXT NOT NULL, \n\torder_id                TEXT,\n\treview_score            INTEGER,\n\treview_comment_title    TEXT,\n\treview_comment_message  TEXT,\n\treview_creation_date    TIMESTAMP,\n\treview_answer_timestamp TIMESTAMP\n)\n\nCREATE TABLE sellers( \n    seller_id                 TEXT,\n    seller_zip_code_prefix    INTEGER,\n    seller_city               TEXT,\n    seller_state              TEXT\n)\n\nCREATE TABLE products( \n    product_id                    TEXT,\n    product_category_name         TEXT,\n    product_name_lenght           REAL,\n    product_description_lenght    REAL,\n    product_photos_qty            REAL,\n    product_weight_g              REAL,\n    product_length_cm             REAL,\n    product_height_cm             REAL,\n    product_width_cm              REAL\n)\n\nCREATE TABLE order_payments( \n    order_id                 TEXT,\n    payment_sequential       INTEGER,\n    payment_type             TEXT,\n    payment_installments     INTEGER,\n    payment_value            REAL\n)\n\nCREATE TABLE customer( \n    customer_id                 TEXT,\n    customer_unique_id          TEXT,\n    customer_zip_code_prefix    INTEGER,  \n    customer_city               TEXT,\n    customer_state              TEXT\n)\n\nCREATE TABLE geolocation( \n    geolocation_zip_code_prefix    INTEGER,\n    geolocation_lat                REAL,\n    geolocation_lng                REAL,\n    geolocation_city               TEXT,\n    geolocation_state              TEXT\n)\n\n\n===Additional Context \n\nTabela `sellers` contém vendedores, localização e identificação.\n\nNunca utilize '%y-%m' ou outros formatos de strftime, apenas '%Y-%m'.\n\nTabela `reviews` contém avaliações de clientes sobre pedidos.\n\nTabela `orders` contém pedidos, status, timestamps de compra e entrega.\n\nTabela `order_items` contém os itens de cada pedido, com preço e frete.\n\nTabela `payments` contém pagamentos de cada pedido.\n\nSempre utilize a função strftime no formato '%Y-%m' para gerar ano e mês no SQLite.\n\nA tabela `order_items` se conecta à tabela `products` pela coluna `product_id` usando LEFT JOIN (pois alguns produtos podem não estar catalogados).\n\nA tabela `orders` se conecta à tabela `order_reviews` pela coluna `order_id` usando LEFT JOIN (nem todo pedido possui review).\n\nTabela `customers` contém informações dos clientes e CEP.\n\n===Response Guidelines \n1. If the provided context is suf ...
# Using model gpt-3.5-turbo for 2951.5 tokens (approx)
# LLM Response:
# ```sql
#             WITH monthly_seller_sales AS (
#                 SELECT
#                     oi.seller_id,
#                     SUM(oi.price) AS total_sales,
#                     COUNT(oi.order_item_id) AS total_items_sold
#                 FROM orders o
#                 JOIN order_items oi ON o.order_id = oi.order_id
#                 WHERE STRFTIME('%Y-%m', o.order_purchase_timestamp) = '2018-08'
#                 GROUP BY oi.seller_id
#             )
#             SELECT
#                 s.seller_id,
#                 s.total_sales,
#                 s.total_items_sold,
#                 RANK() OVER (ORDER BY s.total_sales DESC) AS sales_rank
#             FROM monthly_seller_sales s
#             ORDER BY sales_rank;
# ```
#
# Extracted SQL: WITH monthly_seller_sales AS (
#                 SELECT
#                     oi.seller_id,
#                     SUM(oi.price) AS total_sales,
#                     COUNT(oi.order_item_id) AS total_items_sold
#                 FROM orders o
#                 JOIN order_items oi ON o.order_id = oi.order_id
#                 WHERE STRFTIME('%Y-%m', o.order_purchase_timestamp) = '2018-08'
#                 GROUP BY oi.seller_id
#             )
#             SELECT
#                 s.seller_id,
#                 s.total_sales,
#                 s.total_items_sold,
#                 RANK() OVER (ORDER BY s.total_sales DESC) AS sales_rank
#             FROM monthly_seller_sales s
#             ORDER BY sales_rank;

# %%
df = vn.run_sql(sql)

# %%
df.head(10)
# Out:
#                           seller_id  total_sales  total_items_sold  sales_rank
# 0  1025f0e2d44d7041d6cf58b6550e0bfa     16791.60               138           1
# 1  53243585a1d6dc2643021fd1853d8905     16438.00                80           2
# 2  4869f7a5dfa277a7dca6462dcf3b52b2     14429.40                86           3
# 3  6560211a19b47992c3666cc44a7e94c0     13354.00               204           4
# 4  6061155addc1e54b4cfb51c1c2a32ad8     11203.50                23           5
# 5  f7ba60f8c3f99e7ee4042fdef03b70c4     10841.00                31           6
# 6  7d13fca15225358621be4086e1eb0964      9812.04                50           7
# 7  fa1c13f2614d7b5c4749cbc52fecda94      8714.80                32           8
# 8  04308b1ee57b6625f47df1d56f00eedf      8500.40                16           9
# 9  240b9776d844d37535668549a396af32      8245.25                25          10

# %%
from matplotlib import pyplot as plt
